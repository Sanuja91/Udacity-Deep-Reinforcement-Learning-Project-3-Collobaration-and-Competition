# %% [markdown]
# # COLLABORATION AND COMPETITION - TENNIS
# _Project for Udacity Deep Reinforcement Learning Nanodegree_
# ---

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# # Project Overview
#
# ## Agent overview
# This code has the flexibility to run either __DDPG (Deep Deterministic Policy Gradient)__ or a __D4PG (Distributed Distributional Deep Deterministic Policy Gradient)__ agents in either the single arm or multi arm environments.
#
# ### Deep Deterministic Policy Gradient Agent
#
# The DDPG uses an __Actor Critic__ architecture to estimate the best action for the current observation of the state. The __Actor__ is a policy based agent the uses a neural network to directly estimate the best policy for the agent while the __Critic__ is a value based agent that determines the value of the action in the given state represented by a _Q value_ given the current observation of the state and the output generated by the Actor.
#
# #### DDPG Learning Process
# The DDPG agent is an off policy agent that utilizes a __Replay Buffer__ to increase its sample efficiency by storing experiences (SARS' tuples) in the replay buffer and sampling batches of experiences to learn from. This allows experiences to be utilized several times to prior to being discarded hence allows an agent to learn the aspects of the environment with fewer observations.
#
# The DDPG agent consists of both __Active and Target__ networks, this is drawn from the concept of __Fixed Q Targets__ presented in the __DQN (Deep Q Network)__ to stabilizes learning by reducing the speed of change of the targets networks that the active network is working toward. This is further evolved in the concept of the DDPG by having target networks for both the Actor and the Critic and then utilizing them to train the Active Critic network.
#
# The Active Critic learns by calculating the __Mean Squared Error Loss__ between its value estimate for the action proposed by the actor for the current observation of the state and the sum of the current reward and the value estimate by the Target Critic for the action proposed by the Target Actor for the observation of the next state. Once the MSE Loss is calculated, the loss back propogated through the Active Critic network to train it using __Gradient Descent__.
#
# The gradients for the the Acitve Critic is clipped to prevent large updates that would destabilize the neural network
#
# The Active Actor is then updated with the negative of the value predicted by the Active Critic performing back propogation to train it using __Gradient Ascent__ in order to maximize the score as the score is a representation of value.
#
#
# ### Distributed Distributional Deep Deterministic Policy Gradient Agent
# The D4PG is an evolution of the DDPG architecture implemented by __Google Deepmind__ recently. The D4PG paper introduces several key concepts to improve performance over the traditional DDPG architecture. These include:
#
# - N-Step Rollouts
# - Prioritized Experience Replay (Not Implemented)
# - K-Actor Distributed Training
# - Distributional Value Estimation
#
# _For simplicity, observation of state will be referred to as state._
#
# #### N-Step Rollouts
# N Step Rollouts are not a new concept but has been incorporated to include a better understanding of value of the state n steps from the current state. N steps is the middle ground between __Monte Carlo Learning__, where the agent learns at the end of every trajectory, and __Temporal Difference Learning__, where the agent learns at every timestep. By using the rollout length of the N steps, we can control how far ahead the agent looks. In this implementation, the __N Step Replay Buffer__ has the capacity to switch in between the standard single experience mode and N step mode. When in N step mode, the agent keeps track of experiences of a certain rollout length, traditionally 5 is used. Once the rollout length is reached, the agent simply converts the set of experiences into a single experience by changing the next state to the state at the N'th step and changing the reward to contain the initial reward and the discounted rewards till the N'th state
#
# #### K-Actor Distributed Training
# K-Actors are used to gather experience and fill the replay buffer, allowing rapid gathering of experience thereby enhancing learning quicker with a diverse set of experiences.
#
# #### Prioritized Replay
# This was not implemented as the agent was easily able to beat the environment. This and the implementation of __Hindsight Experience Replay__ will be really interesting to evaluate
#
# #### Distributional Value Estimation
# This allows the Critic to estimate the value more accurately by using a probability distribution to estimate the probability of a value. This allows the agent to understand the there is X% chance to result in a value but there also Y% chance to result in this value. This gives the Critic a wider perception of the possiblities thereby making the Critic perform better. Since the loss that is used to update the Actor is the negative of the value estimated by the Critic, improving the Critic will directly improve the Actor resulting in better performance of the agent.
#
#
# ### Implemented Tweaks
#
# #### Reward Hacking
# I implemented reward hacking to adjust the rewards to attain better performance by creating a reward hypothesis which I personally felt was better suited for the environment. These hacked rewards are not used in the calculation of the scores, only in the creating of experience tuples hence it only affects the learning.
#
# Currently the agent receives a reward 0.1 for being hitting the ball over the net and a reward of -0.01 for hitting the ball out of bounds or letting it drop. I simply modified the rewards with somewhat of a wrapper to somewhat duplicate rewards. Basically I give the same reward to the agent at play and additionally give 10% of the reward to the other agent. This percentage controlled by the alternative_reward_scalar variable. The ideology behind this is that the collaborative agent will provide a good ball to the other agent by sharing the rewards of the other agent with the collaborative agent. The rewards currently seem to keep the agents disconnected. I merely linked them here.
#
# #### Batch Normalization
# Batch Normalization allows the normalization of the at each stage as it moves from the hidden layers output to the __Activation Function__ thereby levelizing and regularizing the data thereby leading to improved and more stable learning. However, this initially wrecked learning when implemented across all layers with __ReLU and Tanh Activations__. By removing the Batch Normalization layers prior to the ReLU activations and keeping the Batch Normalization prior to the Tanh activations resulted in much more stable learning even outperforming implementations with and Batch Normalization layers. I believe this is because Tanh simply outputs majority of values in between a small range unlike ReLU and is aided much more so with regularized inputs.
#
# #### Delayed Hard Target Network Updates
# Instead of using the traditional soft updates where the Target networks are updated with the parameters from the Active networks by scaling the parameters down with a factor of __TAU__. The Target networks were updated every x timesteps with a hard update from the Active networks. This seemed to stabilize learning further from my experience
#
# #### Pre - Training
# When the agent is started the agent generates experiences with the use of random actions without forward prograting through the network. This fills up the replay buffer quickly resulting in gathering experiences performed with a much broader exploration outlook. This seems to help the agent get through the essential first steps of learning by learning from a diverse set of experiences before simply using __Gaussian Noise__ for the actions creating somewhat of less of a diverse variety of experiences later on but closer to the specific direction in which the agent is heading.
#
#
# ### Failed Tweaks
#
# #### Scheduled Learning Rates
# Scheduling the learning rates to reduce on performance plateaus were tested. This to cause problems when the agent hits local optimums as the agent drastically reduces its learning the longer its stuck in a local optima thereby hinders itself to moving out of the local optima by having its capacity to learn being pulled out right under it.
#
# _This could possibly prove to work if the patience factor in between the updates is increased thereby the agents learning rate is decreased less frequently_
#
# #### Cyclical Learning Rates
# Updating the learning rates periodically by multiplying the base learning to the oscillations of a __Cosine Function__ resulting in learning cycling between a value range. This seems to cause subtantial instability in the network and the agent sometimes gets thrown off a cliff once it has converged as the learning rate gets too high.
#
# _This could possibly prove to work if the base learning rate is kept lower preventing the agent from being thrown off a cliff_
#
# #### Parameter Noise
# This was suggested in OpenAIs paper in encourage exploration and that it performs better than both Gaussian and OU Noise allowing for learning in some sense similar to an __Evolutionary Alogrithm__. I tried adding little bits of noise to the network weights / parameters several times but this seemed to wreck any learning even.
#
# _This could possibly prove to work if extremely tiny bits of noise is added to the parameters. I find it questionable as it causes substantial instability in the environment_
#
# #### Delayed Intensive Updates
# This ideology was obtained from the Udacity benchmark implementation. I personally found this to result in greater instability resulting in slower convergence. For testing, I updated the agents every 20 timesteps 10 times in a row.
#
# _Honeslty speaking, I don't think there is much point in this tweak_
#
#
# ### The Results
#
# The scores were tracked using Tensorboard along with the losses of the Actor and the Critic. The agent seems to converge faster than the benchmark implementation and remains stable after convergence with minor improvements over time. The Max Score represents the maximum score out of the two agents
#
# #### Tracked by Tensorboard

# %% [markdown]
# ![TITLE](images/Results.jpg)

# %% [markdown]
# ### Hyper Parameter Selection
#
# __ACTOR LEARNING RATE / CRITIC LEARNING RATE__ - Tests were run with several learning rates in between 0.0005 to 0.0001 for the Actor and learning rates in between 0.001 to 0.0005 for the Critic. The D4PG seems to be quite a robust network being able to eventually converge either which way
#
# __EPSILON__ - This is the control used to tweak the Gaussian Noise that is added to the action thereby it is the variable that we use to control exploration of the environment. This was set to 0.3 and not annealed throughout the training
#
# __PRETRAIN__ - The number of random experiences that are required to be generated and filled into the replay buffer before proceeding with training the agent using Gradient Descent
#
# __UPDATE_TARGETS_EVERY__ - This is the control used to determine how frequently the parameters from the Active networks are used to update the Target networks. This was set to 350
#
# __ROLLOUT LENGTH__ - This is used to determine the rollout length used by the N step replay buffer to decide how far ahead the agent should look into
#
# __ATOMS__ - This controls the granularity with which the probability distribution is estimated from the Q network. The more atoms there are, the greater the granularity of the distribution.
#
# __VMIN / VMAN__ - The bounds of the values predicted by the agent. The atoms are distributed between these two values which in turn are multiplied by the probabilities from the Critic network to arrive at the value distribution.

# %% [markdown]
# ### 1. Initialize the Environment
# Run the below section once to initialize the environment.. Don't Repeat!!!

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, two agents control rackets to bounce a ball over a net. If an agent hits the ball over the net, it receives a reward of +0.1.  If an agent lets a ball hit the ground or hits the ball out of bounds, it receives a reward of -0.01.  Thus, the goal of each agent is to keep the ball in play.
#
# The observation space consists of 8 variables corresponding to the position and velocity of the ball and racket. Two continuous actions are available, corresponding to movement toward (or away from) the net, and jumping.
#
# Run the code cell below to print some information about the environment.

# %%
from utilities import Seeds, initialize_env, get_device

device = get_device()                           # gets gpu if available

environment_params = {
    'no_graphics': False,                       # runs no graphics windows version
    'train_mode': True,                         # runs in train mode
    'offline': True,                            # toggle on for udacity jupyter notebook 
    'device': device
}

env, env_info, states, state_size, action_size, brain_name, num_agents = initialize_env(environment_params)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: TennisBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 8
#         Number of stacked Vector Observation: 3
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 2
#         Vector Action descriptions: ,
# Number of agents: 2
# Number of actions: 2
# States have length: 24
# States initialized: 2
# Number of Agents: 2

# %% [markdown]
# ### 2. Configure the Agent
# Configures the respective 'knobs' on the agent to beat the environment.. The best configurations from my experiments have already been set.
#
# To load the complete version of the agent, please run as is. If you want test the agent from scratch, simply change the name in agent params and re run

# %%
from unityagents import UnityEnvironment
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import torch.nn.functional as F
import torch.nn as nn

from agent import D4PGAgent
from train import train
from memory import NStepReplayBuffer
from noise import OUNoise, GaussianExploration


seedGenerator = Seeds('seeds')
seedGenerator.next()

experience_params = {
    'seed': seedGenerator,                      # seed for the experience replay buffer
    'buffer_size': 300000,                      # size of the replay buffer
    'batch_size': 128,                          # batch size sampled from the replay buffer
    'rollout_length': 15,                        # n step rollout length    
    'agent_count': 2,
    'gamma': 0.99,
    'device': device
}

experienceReplay = NStepReplayBuffer(experience_params)

noise_params = {
    'ou_noise_params': {                        # parameters for the Ornstein Uhlenbeck process
        'mu': 0.,                               # mean
        'theta': 0.15,                          # theta value for the ornstein-uhlenbeck process
        'sigma': 0.2,                           # variance
        'seed': seedGenerator,                  # seed
        'action_size': action_size  
    },  
    'ge_noise_params': {                        # parameters for the Gaussian Exploration process                   
        'max_epsilon': 0.3,                     
        'min_epsilon': 0.005,   
        'decay_epsilon': True,      
        'patience_episodes': 2,                 # episodes since the last best reward  
        'decay_rate': 0.95                   
    }
}

noise = GaussianExploration(noise_params['ge_noise_params'])

params = {
    'episodes': 2000,                           # number of episodes
    'maxlen': 100,                              # sliding window size of recent scores
    'brain_name': brain_name,                   # the brain name of the unity environment
    'achievement': 0.5,                         # score at which the environment is considered beaten
    'achievement_length': 100,                  # how long the agent needs to get a score above the achievement to solve the environment
    'environment': env,             
    'pretrain': True,                           # whether pretraining with random actions should be done
    'pretrain_length': 5000,                   # minimum experience required in replay buffer to start training 
    'random_fill': False,                       # basically repeat pretrain at specific times to encourage further exploration
    'random_fill_every': 10000,             
    'hack_rewards': True,                       # hack rewards
    'alternative_reward_scalar': 0.1,           # scales other agents rewards to current agent
    'log_dir': 'runs/',
    'load_agent': True,
    'save_every': 1000,                         # save every x episodes
    'agent_params': {
        'name': 'D4PG - High Rollout',
        'd4pg': True,
        'experience_replay': experienceReplay,
        'device': device,
        'seed': seedGenerator,
        'num_agents': num_agents,               # number of agents in the environment
        'gamma': 0.99,                          # discount factor
        'tau': 0.0001,                          # mixing rate soft-update of target parameters
        'update_target_every': 350,             # update the target network every n-th step
        'update_every': 1,                      # update the active network every n-th step
        'actor_update_every_multiplier': 1,     # update actor every x timestep multiples of the crtic, critic needs time to adapt to new actor
        'update_intensity': 1,                  # learns from the same experiences several times
        'update_target_type': 'hard',           # should the update be soft at every time step or hard at every x timesteps
        'add_noise': True,                      # add noise using 'noise_params'
        'schedule_lr': False,                   # schedule learning rates 
        'lr_steps': 30,                         # step iterations to cycle lr using cosine
        'lr_reset_every': 5000,                 # steps learning rate   
        'lr_reduction_factor': 0.9,             # reduce lr on plateau reduction factor
        'lr_patience_factor': 10,               # reduce lr after x (timesteps/episodes) not changing tracked item
        'actor_params': {                       # actor parameters
            'lr': 0.0001,                       # learning rate
            'state_size': state_size,           # size of the state space
            'action_size': action_size,         # size of the action space
            'seed': seedGenerator,              # seed of the network architecture
        },
        'critic_params': {                      # critic parameters
            'lr': 0.0005,                        # learning rate
            'weight_decay': 3e-10,              # weight decay
            'state_size': state_size,           # size of the state space
            'action_size': action_size,         # size of the action space
            'seed': seedGenerator,              # seed of the network architecture
            'action_layer': True,
            'num_atoms': 75,
            'v_min': 0.0, 
            'v_max': 0.5
        },
        'noise': noise
    }
}

# %% [markdown]
# ### 3. Train the Agent
# Get the agent to learn to beat the environment and output the scores

# %%
agents = D4PGAgent(params=params['agent_params']) 

scores = train(agents=agents, params=params, num_processes=num_agents)

df = pd.DataFrame(data={'episode': np.arange(len(scores)), 'D4PG': scores})
df.to_csv('results/D4PG.csv', index=False)
# Out:
# ################ ACTOR ################
#
# Actor(
#   (fc1): Sequential(
#     (0): Linear(in_features=24, out_features=400, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=400, out_features=300, bias=True)
#     (1): ReLU()
#   )
#   (fc3): Sequential(
#     (0): Linear(in_features=300, out_features=2, bias=True)
#     (1): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Tanh()
#   )
# )
#
# ################ CRITIC ################
#
# D4PGCritic(
#   (fc1): Sequential(
#     (0): Linear(in_features=26, out_features=400, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=400, out_features=300, bias=True)
#     (1): ReLU()
#   )
#   (fc3): Sequential(
#     (0): Linear(in_features=300, out_features=75, bias=True)
#     (1): ReLU()
#   )
# )
# Loading checkpoint - Average Reward 0.1212500019930303 at Episode 289
# Episode 290	Max: 0.00 	 Time: 0.04
# Episode 291	Max: 0.00 	 Time: 0.22
# Episode 292	Max: 0.10 	 Time: 0.08
# Episode 293	Max: 0.00 	 Time: 0.04
# Episode 294	Max: 0.09 	 Time: 0.08
# Episode 295	Max: 0.00 	 Time: 0.04
# Episode 296	Max: 0.00 	 Time: 0.04
# Episode 297	Max: 0.00 	 Time: 0.03
# Episode 298	Max: 0.00 	 Time: 0.03
# Episode 299	Max: 0.00 	 Time: 0.03
# Episode 300	Max: 0.00 	 Time: 0.03
# Episode 301	Max: 0.10 	 Time: 0.07
# Episode 302	Max: 0.00 	 Time: 0.03
# Episode 303	Max: 0.10 	 Time: 0.09
# Episode 304	Max: 0.00 	 Time: 0.03
# Episode 305	Max: 0.00 	 Time: 0.03
# Episode 306	Max: 0.00 	 Time: 0.03
# Episode 307	Max: 0.00 	 Time: 0.03
# Episode 308	Max: 0.00 	 Time: 0.03
# Episode 309	Max: 0.00 	 Time: 0.03
# Episode 310	Max: 0.09 	 Time: 0.07
# Episode 311	Max: 0.10 	 Time: 0.12
# Episode 312	Max: 0.10 	 Time: 0.07
# Episode 313	Max: 0.00 	 Time: 0.03
# Episode 314	Max: 0.00 	 Time: 0.04
# Episode 315	Max: 0.00 	 Time: 0.04
# Episode 316	Max: 0.00 	 Time: 0.03
# Episode 317	Max: 0.00 	 Time: 0.03
# Episode 318	Max: 0.00 	 Time: 0.03
# Episode 319	Max: 0.10 	 Time: 0.07
# Episode 320	Max: 0.00 	 Time: 0.03
# Episode 321	Max: 0.00 	 Time: 0.04
# Episode 322	Max: 0.00 	 Time: 0.04
# Episode 323	Max: 0.00 	 Time: 0.04
# Episode 324	Max: 0.00 	 Time: 0.03
# Episode 325	Max: 0.00 	 Time: 0.03
# Episode 326	Max: 0.00 	 Time: 0.03
# Episode 327	Max: 0.10 	 Time: 0.07
# Episode 328	Max: 0.00 	 Time: 0.03
# Episode 329	Max: 0.00 	 Time: 0.03
# Episode 330	Max: 0.00 	 Time: 0.04
# Episode 331	Max: 0.10 	 Time: 0.07
# Episode 332	Max: 0.00 	 Time: 0.03
# Episode 333	Max: 0.00 	 Time: 0.03
# Episode 334	Max: 0.10 	 Time: 0.11
# Episode 335	Max: 0.00 	 Time: 0.03
# Episode 336	Max: 0.10 	 Time: 0.05
# Episode 337	Max: 0.00 	 Time: 0.03
# Episode 338	Max: 0.00 	 Time: 0.04
# Episode 339	Max: 0.00 	 Time: 0.03
# Episode 340	Max: 0.00 	 Time: 0.04
# Episode 341	Max: 0.00 	 Time: 0.04
# Episode 342	Max: 0.00 	 Time: 0.03
# Episode 343	Max: 0.00 	 Time: 0.03
# Episode 344	Max: 0.00 	 Time: 0.04
# Episode 345	Max: 0.09 	 Time: 0.08
# Episode 346	Max: 0.00 	 Time: 0.03
# Episode 347	Max: 0.00 	 Time: 0.03
# Episode 348	Max: 0.00 	 Time: 0.03
# Episode 349	Max: 0.00 	 Time: 0.03
# Episode 350	Max: 0.00 	 Time: 0.04
# Episode 351	Max: 0.20 	 Time: 0.15
# Episode 352	Max: 0.00 	 Time: 0.08
# Episode 353	Max: 0.00 	 Time: 0.03
# Episode 354	Max: 0.00 	 Time: 0.03
# Episode 355	Max: 0.00 	 Time: 0.03
# Episode 356	Max: 0.00 	 Time: 0.04
# Episode 357	Max: 0.00 	 Time: 0.03
# Episode 358	Max: 0.00 	 Time: 0.03
# Episode 359	Max: 0.00 	 Time: 0.03
# Episode 360	Max: 0.10 	 Time: 0.07
# Episode 361	Max: 0.00 	 Time: 0.03
# Episode 362	Max: 0.00 	 Time: 0.03
# Episode 363	Max: 0.00 	 Time: 0.04
# Episode 364	Max: 0.00 	 Time: 0.03
# Episode 365	Max: 0.00 	 Time: 0.03
# Episode 366	Max: 0.00 	 Time: 0.03
# Episode 367	Max: 0.00 	 Time: 0.03
# Episode 368	Max: 0.00 	 Time: 0.03
# Episode 369	Max: 0.00 	 Time: 0.03
# Episode 370	Max: 0.00 	 Time: 0.03
# Episode 371	Max: 0.00 	 Time: 0.03
# Episode 372	Max: 0.00 	 Time: 0.03
# Episode 373	Max: 0.00 	 Time: 0.03
# Episode 374	Max: 0.00 	 Time: 0.04
# Episode 375	Max: 0.00 	 Time: 0.03
# Episode 376	Max: 0.00 	 Time: 0.03
# Episode 377	Max: 0.00 	 Time: 0.04
# Episode 378	Max: 0.00 	 Time: 0.04
# Episode 379	Max: 0.10 	 Time: 0.06
# Episode 380	Max: 0.00 	 Time: 0.03
# Episode 381	Max: 0.00 	 Time: 0.04
# Episode 382	Max: 0.00 	 Time: 0.04
# Episode 383	Max: 0.00 	 Time: 0.04
# Episode 384	Max: 0.00 	 Time: 0.08
# Episode 385	Max: 0.10 	 Time: 0.07
# Episode 386	Max: 0.10 	 Time: 0.07
# Episode 387	Max: 0.10 	 Time: 0.07
# Episode 388	Max: 0.00 	 Time: 0.03
# Episode 389	Max: 0.00 	 Time: 0.04
# Episode 390	Max: 0.00 	 Time: 0.03
# Episode 391	Max: 0.00 	 Time: 0.03
# Episode 392	Max: 0.00 	 Time: 0.03
# Episode 393	Max: 0.00 	 Time: 0.03
# Episode 394	Max: 0.00 	 Time: 0.03
# Episode 395	Max: 0.00 	 Time: 0.04
# Episode 396	Max: 0.00 	 Time: 0.04
# Episode 397	Max: 0.00 	 Time: 0.03
# Episode 398	Max: 0.00 	 Time: 0.03
# Episode 399	Max: 0.00 	 Time: 0.04
# Episode 400	Max: 0.00 	 Time: 0.03
# Episode 401	Max: 0.09 	 Time: 0.08
# Episode 402	Max: 0.00 	 Time: 0.03
# Episode 403	Max: 0.00 	 Time: 0.03
# Episode 404	Max: 0.00 	 Time: 0.03
# Episode 405	Max: 0.00 	 Time: 0.03
# Episode 406	Max: 0.09 	 Time: 0.07
# Episode 407	Max: 0.00 	 Time: 0.03
# Episode 408	Max: 0.00 	 Time: 0.03
# Episode 409	Max: 0.00 	 Time: 0.04
# Episode 410	Max: 0.00 	 Time: 0.03
# Episode 411	Max: 0.00 	 Time: 0.03
# Episode 412	Max: 0.00 	 Time: 0.03
# Episode 413	Max: 0.00 	 Time: 0.03
# Episode 414	Max: 0.00 	 Time: 0.03
# Episode 415	Max: 0.09 	 Time: 0.07
# Episode 416	Max: 0.10 	 Time: 0.12
# Episode 417	Max: 0.10 	 Time: 0.12
# Episode 418	Max: 0.00 	 Time: 0.03
# Episode 419	Max: 0.10 	 Time: 0.11
# Episode 420	Max: 0.10 	 Time: 0.07
# Episode 421	Max: 0.00 	 Time: 0.03
# Episode 422	Max: 0.00 	 Time: 0.03
# Episode 423	Max: 0.00 	 Time: 0.03
# Episode 424	Max: 0.30 	 Time: 11.62
# Episode 425	Max: 0.10 	 Time: 2.82
# Episode 426	Max: 0.00 	 Time: 1.25
# Episode 427	Max: 0.00 	 Time: 2.66
# Episode 428	Max: 0.10 	 Time: 2.74
# Episode 429	Max: 0.10 	 Time: 2.74
# Episode 430	Max: 0.10 	 Time: 3.54
# Episode 431	Max: 0.09 	 Time: 2.75
# Episode 432	Max: 0.00 	 Time: 1.23
# Episode 433	Max: 0.00 	 Time: 1.23
# Episode 434	Max: 0.10 	 Time: 2.65
# Episode 435	Max: 0.00 	 Time: 1.25
# Episode 436	Max: 0.09 	 Time: 2.76
# Episode 437	Max: 0.10 	 Time: 2.91
# Episode 438	Max: 0.20 	 Time: 8.59
# Episode 439	Max: 0.10 	 Time: 2.90
# Episode 440	Max: 0.00 	 Time: 1.31
# Episode 441	Max: 0.00 	 Time: 1.40
# Episode 442	Max: 0.09 	 Time: 2.64
# Episode 443	Max: 0.10 	 Time: 4.51
# Episode 444	Max: 0.30 	 Time: 9.53
# Episode 445	Max: 0.10 	 Time: 4.46
# Episode 446	Max: 0.20 	 Time: 5.45
# Episode 447	Max: 0.10 	 Time: 2.75
# Episode 448	Max: 0.10 	 Time: 2.75
# Episode 449	Max: 0.09 	 Time: 1.51
# Episode 450	Max: 0.10 	 Time: 2.75
# Episode 451	Max: 0.09 	 Time: 2.54
# Episode 452	Max: 0.10 	 Time: 2.82
# Episode 453	Max: 0.10 	 Time: 2.64
# Episode 454	Max: 0.20 	 Time: 6.17
# Episode 455	Max: 0.00 	 Time: 1.34
# Episode 456	Max: 0.00 	 Time: 1.24
# Episode 457	Max: 0.10 	 Time: 2.78
# Episode 458	Max: 0.09 	 Time: 2.64
# Episode 459	Max: 0.10 	 Time: 2.70
# Episode 460	Max: 0.10 	 Time: 4.62
# Episode 461	Max: 0.10 	 Time: 5.61
# Episode 462	Max: 0.10 	 Time: 2.58
# Episode 463	Max: 0.20 	 Time: 7.95
# Episode 464	Max: 0.10 	 Time: 2.68
# Episode 465	Max: 0.10 	 Time: 2.56
# Episode 466	Max: 0.20 	 Time: 7.77
# Episode 467	Max: 0.10 	 Time: 2.57
# Episode 468	Max: 0.20 	 Time: 6.08
# Episode 469	Max: 0.09 	 Time: 2.83
# Episode 470	Max: 0.29 	 Time: 9.59
# Episode 471	Max: 0.20 	 Time: 8.01
# Episode 472	Max: 0.10 	 Time: 2.94
# Episode 473	Max: 0.70 	 Time: 24.69
# Episode 474	Max: 0.10 	 Time: 1.96
# Episode 475	Max: 0.50 	 Time: 16.41
# Episode 476	Max: 0.20 	 Time: 7.99
# Episode 477	Max: 0.10 	 Time: 4.66
# Episode 478	Max: 0.10 	 Time: 2.59
# Episode 479	Max: 0.50 	 Time: 15.93
# Episode 480	Max: 0.10 	 Time: 4.63
# Episode 481	Max: 0.10 	 Time: 2.56
# Episode 482	Max: 0.10 	 Time: 2.60
# Episode 483	Max: 0.20 	 Time: 7.55
# Episode 484	Max: 0.10 	 Time: 2.67
# Episode 485	Max: 0.10 	 Time: 4.36
# Episode 486	Max: 0.10 	 Time: 4.47
# Episode 487	Max: 0.50 	 Time: 16.38
# Episode 488	Max: 0.20 	 Time: 6.42
# Episode 489	Max: 0.20 	 Time: 6.42
# Episode 490	Max: 0.10 	 Time: 2.04
# Episode 491	Max: 0.20 	 Time: 7.80
# Episode 492	Max: 0.10 	 Time: 2.84
# Episode 493	Max: 0.20 	 Time: 7.93
# Episode 494	Max: 0.10 	 Time: 4.65
# Episode 495	Max: 0.20 	 Time: 7.94
# Episode 496	Max: 0.20 	 Time: 6.24
# Episode 497	Max: 0.10 	 Time: 4.85
# Episode 498	Max: 0.10 	 Time: 2.78
# Episode 499	Max: 0.10 	 Time: 4.56
# Episode 500	Max: 0.40 	 Time: 12.65
# Episode 501	Max: 0.20 	 Time: 6.48
# Episode 502	Max: 0.29 	 Time: 10.83
# Episode 503	Max: 0.10 	 Time: 4.55
# Episode 504	Max: 0.00 	 Time: 1.30
# Episode 505	Max: 0.00 	 Time: 1.70
# Episode 506	Max: 0.49 	 Time: 16.12
# Episode 507	Max: 0.30 	 Time: 11.60
# Episode 508	Max: 0.10 	 Time: 2.77
# Episode 509	Max: 0.10 	 Time: 2.78
# Episode 510	Max: 0.39 	 Time: 12.74
# Episode 511	Max: 0.30 	 Time: 11.32
# Episode 512	Max: 0.10 	 Time: 4.54
# Episode 513	Max: 0.20 	 Time: 5.59
# Episode 514	Max: 0.30 	 Time: 9.65
# Episode 515	Max: 0.00 	 Time: 1.25
# Episode 516	Max: 0.20 	 Time: 8.02
# Episode 517	Max: 0.10 	 Time: 2.68
# Episode 518	Max: 0.20 	 Time: 6.30
# Episode 519	Max: 0.30 	 Time: 9.64
# Episode 520	Max: 0.10 	 Time: 4.65
# Episode 521	Max: 0.30 	 Time: 9.59
# Episode 522	Max: 0.20 	 Time: 6.39
# Episode 523	Max: 0.20 	 Time: 7.98
# Episode 524	Max: 0.20 	 Time: 7.91
# Episode 525	Max: 0.60 	 Time: 19.70
# Episode 526	Max: 0.00 	 Time: 1.89
# Episode 527	Max: 0.20 	 Time: 8.02
# Episode 528	Max: 0.09 	 Time: 2.69
# Episode 529	Max: 0.10 	 Time: 2.78
# Episode 530	Max: 0.20 	 Time: 6.25
# Episode 531	Max: 0.20 	 Time: 7.93
# Episode 532	Max: 0.20 	 Time: 6.43
# Episode 533	Max: 0.10 	 Time: 2.63
# Episode 534	Max: 0.10 	 Time: 2.57
# Episode 535	Max: 0.20 	 Time: 8.04
# Episode 536	Max: 0.10 	 Time: 2.81
# Episode 537	Max: 0.20 	 Time: 8.01
# Episode 538	Max: 0.20 	 Time: 6.22
# Episode 539	Max: 0.00 	 Time: 1.33
# Episode 540	Max: 0.10 	 Time: 2.67
# Episode 541	Max: 0.20 	 Time: 6.33
# Episode 542	Max: 0.00 	 Time: 1.24
# Episode 543	Max: 0.00 	 Time: 1.25
# Episode 544	Max: 0.10 	 Time: 2.65
# Episode 545	Max: 0.10 	 Time: 2.79
# Episode 546	Max: 0.20 	 Time: 6.19
# Episode 547	Max: 0.20 	 Time: 6.35
# Episode 548	Max: 0.00 	 Time: 1.27
# Episode 549	Max: 0.10 	 Time: 2.87
# Episode 550	Max: 0.20 	 Time: 8.01
# Episode 551	Max: 0.10 	 Time: 4.52
# Episode 552	Max: 0.20 	 Time: 6.35
# Episode 553	Max: 0.10 	 Time: 4.54
# Episode 554	Max: 0.30 	 Time: 9.89
# Episode 555	Max: 0.10 	 Time: 4.43
# Episode 556	Max: 0.10 	 Time: 2.77
# Episode 557	Max: 0.10 	 Time: 2.60
# Episode 558	Max: 0.09 	 Time: 2.76
# Episode 559	Max: 0.30 	 Time: 9.55
# Episode 560	Max: 0.10 	 Time: 4.70
# Episode 561	Max: 0.10 	 Time: 2.76
# Episode 562	Max: 0.10 	 Time: 2.75
# Episode 563	Max: 0.20 	 Time: 6.33
# Episode 564	Max: 0.10 	 Time: 3.53
# Episode 565	Max: 0.10 	 Time: 5.78
# Episode 566	Max: 0.30 	 Time: 9.65
# Episode 567	Max: 0.20 	 Time: 6.41
# Episode 568	Max: 0.30 	 Time: 9.57
# Episode 569	Max: 0.10 	 Time: 2.67
# Episode 570	Max: 0.30 	 Time: 9.74
# Episode 571	Max: 0.10 	 Time: 4.55
# Episode 572	Max: 0.10 	 Time: 2.75
# Episode 573	Max: 0.10 	 Time: 2.59
# Episode 574	Max: 0.20 	 Time: 8.18
# Episode 575	Max: 0.10 	 Time: 2.68
# Episode 576	Max: 0.20 	 Time: 6.14
# Episode 577	Max: 0.10 	 Time: 4.55
# Episode 578	Max: 0.10 	 Time: 4.64
# Episode 579	Max: 0.10 	 Time: 4.56
# Episode 580	Max: 0.10 	 Time: 4.61
# Episode 581	Max: 0.10 	 Time: 2.77
# Episode 582	Max: 0.10 	 Time: 2.79
# Episode 583	Max: 0.10 	 Time: 2.69
# Episode 584	Max: 0.10 	 Time: 4.67
# Episode 585	Max: 0.00 	 Time: 1.27
# Episode 586	Max: 0.20 	 Time: 7.98
# Episode 587	Max: 0.00 	 Time: 1.60
# Episode 588	Max: 0.00 	 Time: 1.24
# Episode 589	Max: 0.20 	 Time: 8.09
# Episode 590	Max: 0.10 	 Time: 2.58
# Episode 591	Max: 0.10 	 Time: 2.94
# Episode 592	Max: 0.10 	 Time: 2.94
# Episode 593	Max: 0.20 	 Time: 6.31
# Episode 594	Max: 0.20 	 Time: 8.06
# Episode 595	Max: 0.30 	 Time: 9.84
# Episode 596	Max: 0.20 	 Time: 6.27
# Episode 597	Max: 0.10 	 Time: 2.60
# Episode 598	Max: 0.10 	 Time: 4.65
# Episode 599	Max: 0.10 	 Time: 4.66
# Episode 600	Max: 0.20 	 Time: 6.33
# Episode 601	Max: 0.30 	 Time: 11.13
# Episode 602	Max: 0.20 	 Time: 6.32
# Episode 603	Max: 0.20 	 Time: 7.95
# Episode 604	Max: 0.10 	 Time: 2.76
# Episode 605	Max: 0.10 	 Time: 4.59
# Episode 606	Max: 0.10 	 Time: 2.60
# Episode 607	Max: 0.20 	 Time: 6.10
# Episode 608	Max: 0.10 	 Time: 2.67
# Episode 609	Max: 0.10 	 Time: 2.82
# Episode 610	Max: 0.30 	 Time: 11.20
# Episode 611	Max: 0.20 	 Time: 8.11
# Episode 612	Max: 0.20 	 Time: 6.14
# Episode 613	Max: 0.10 	 Time: 4.55
# Episode 614	Max: 0.19 	 Time: 6.22
# Episode 615	Max: 0.10 	 Time: 2.59
# Episode 616	Max: 0.10 	 Time: 4.61
# Episode 617	Max: 0.10 	 Time: 2.76
# Episode 618	Max: 0.10 	 Time: 2.59
# Episode 619	Max: 0.10 	 Time: 4.63
# Episode 620	Max: 0.20 	 Time: 6.30
# Episode 621	Max: 0.30 	 Time: 9.52
# Episode 622	Max: 0.10 	 Time: 2.93
# Episode 623	Max: 0.20 	 Time: 7.99
# Episode 624	Max: 0.20 	 Time: 6.32
# Episode 625	Max: 0.10 	 Time: 2.70
# Episode 626	Max: 0.20 	 Time: 6.44
# Episode 627	Max: 0.20 	 Time: 6.18
# Episode 628	Max: 0.10 	 Time: 4.66
# Episode 629	Max: 0.10 	 Time: 4.62
# Episode 630	Max: 0.10 	 Time: 2.60
# Episode 631	Max: 0.00 	 Time: 1.25
# Episode 632	Max: 0.20 	 Time: 8.06
# Episode 633	Max: 0.09 	 Time: 2.77
# Episode 634	Max: 0.20 	 Time: 6.11
# Episode 635	Max: 0.40 	 Time: 13.04
# Episode 636	Max: 0.00 	 Time: 1.25
# Episode 637	Max: 0.00 	 Time: 2.05
# Episode 638	Max: 0.09 	 Time: 2.76
# Episode 639	Max: 0.10 	 Time: 4.80
# Episode 640	Max: 0.19 	 Time: 6.21
# Episode 641	Max: 0.10 	 Time: 4.66
# Episode 642	Max: 0.20 	 Time: 6.05
# Episode 643	Max: 0.10 	 Time: 4.62
# Episode 644	Max: 0.10 	 Time: 2.57
# Episode 645	Max: 0.10 	 Time: 2.78
# Episode 646	Max: 0.20 	 Time: 6.30
# Episode 647	Max: 0.10 	 Time: 2.76
# Episode 648	Max: 0.10 	 Time: 4.56
# Episode 649	Max: 0.10 	 Time: 2.70
# Episode 650	Max: 0.10 	 Time: 4.63
# Episode 651	Max: 0.20 	 Time: 8.12
# Episode 652	Max: 0.20 	 Time: 6.32
# Episode 653	Max: 0.00 	 Time: 1.26
# Episode 654	Max: 0.29 	 Time: 9.48
# Episode 655	Max: 0.20 	 Time: 6.48
# Episode 656	Max: 0.20 	 Time: 6.28
# Episode 657	Max: 0.10 	 Time: 2.67
# Episode 658	Max: 0.19 	 Time: 6.21
# Episode 659	Max: 0.39 	 Time: 12.96
# Episode 660	Max: 0.30 	 Time: 11.57
# Episode 661	Max: 0.20 	 Time: 9.40
# Episode 662	Max: 0.19 	 Time: 6.23
# Episode 663	Max: 0.00 	 Time: 1.35
# Episode 664	Max: 0.00 	 Time: 1.34
# Episode 665	Max: 0.10 	 Time: 2.77
# Episode 666	Max: 0.10 	 Time: 4.65
# Episode 667	Max: 0.10 	 Time: 4.69
# Episode 668	Max: 0.10 	 Time: 4.52
# Episode 669	Max: 0.20 	 Time: 8.00
# Episode 670	Max: 0.10 	 Time: 2.58
# Episode 671	Max: 0.10 	 Time: 4.54
# Episode 672	Max: 0.10 	 Time: 4.67
# Episode 673	Max: 0.20 	 Time: 6.32
# Episode 674	Max: 0.10 	 Time: 2.97
# Episode 675	Max: 0.20 	 Time: 6.35
# Episode 676	Max: 0.30 	 Time: 11.31
# Episode 677	Max: 0.10 	 Time: 2.80
# Episode 678	Max: 0.10 	 Time: 2.66
# Episode 679	Max: 0.20 	 Time: 8.04
# Episode 680	Max: 0.20 	 Time: 8.00
# Episode 681	Max: 0.30 	 Time: 9.32
# Episode 682	Max: 0.00 	 Time: 1.35
# Episode 683	Max: 0.20 	 Time: 6.18
# Episode 684	Max: 0.00 	 Time: 1.33
# Episode 685	Max: 0.20 	 Time: 8.02
# Episode 686	Max: 0.10 	 Time: 4.62
# Episode 687	Max: 0.00 	 Time: 1.26
# Episode 688	Max: 0.30 	 Time: 9.76
# Episode 689	Max: 0.10 	 Time: 4.22
# Episode 690	Max: 0.10 	 Time: 2.67
# Episode 691	Max: 0.10 	 Time: 2.86
# Episode 692	Max: 0.10 	 Time: 4.53
# Episode 693	Max: 0.10 	 Time: 2.59
# Episode 694	Max: 0.10 	 Time: 2.67
# Episode 695	Max: 0.10 	 Time: 4.62
# Episode 696	Max: 0.09 	 Time: 2.68
# Episode 697	Max: 0.10 	 Time: 4.63
# Episode 698	Max: 0.10 	 Time: 4.66
# Episode 699	Max: 0.20 	 Time: 6.44
# Episode 700	Max: 0.20 	 Time: 6.30
# Episode 701	Max: 0.10 	 Time: 2.70
# Episode 702	Max: 0.10 	 Time: 3.12
# Episode 703	Max: 0.40 	 Time: 14.77
# Episode 704	Max: 0.20 	 Time: 5.98
# Episode 705	Max: 0.10 	 Time: 4.70
# Episode 706	Max: 0.10 	 Time: 2.68
# Episode 707	Max: 0.20 	 Time: 6.28
# Episode 708	Max: 0.20 	 Time: 8.01
# Episode 709	Max: 0.30 	 Time: 9.43
# Episode 710	Max: 0.30 	 Time: 9.44
# Episode 711	Max: 0.30 	 Time: 9.55
# Episode 712	Max: 0.20 	 Time: 8.04
# Episode 713	Max: 0.10 	 Time: 4.51
# Episode 714	Max: 0.30 	 Time: 9.73
# Episode 715	Max: 0.00 	 Time: 1.67
# Episode 716	Max: 0.19 	 Time: 6.41
# Episode 717	Max: 0.10 	 Time: 2.76
# Episode 718	Max: 0.20 	 Time: 6.42
# Episode 719	Max: 0.20 	 Time: 7.83
# Episode 720	Max: 0.10 	 Time: 2.68
# Episode 721	Max: 0.10 	 Time: 4.63
# Episode 722	Max: 0.10 	 Time: 5.88
# Episode 723	Max: 0.09 	 Time: 2.70
# Episode 724	Max: 0.20 	 Time: 6.17
# Episode 725	Max: 0.10 	 Time: 2.69
# Episode 726	Max: 0.10 	 Time: 2.59
# Episode 727	Max: 0.20 	 Time: 6.33
# Episode 728	Max: 0.10 	 Time: 2.59
# Episode 729	Max: 0.20 	 Time: 6.40
# Episode 730	Max: 0.20 	 Time: 6.32
# Episode 731	Max: 0.20 	 Time: 6.17
# Episode 732	Max: 0.20 	 Time: 8.02
# Episode 733	Max: 0.10 	 Time: 2.58
# Episode 734	Max: 0.20 	 Time: 7.30
# Episode 735	Max: 0.00 	 Time: 1.28
# Episode 736	Max: 0.10 	 Time: 4.67
# Episode 737	Max: 0.00 	 Time: 1.26
# Episode 738	Max: 0.20 	 Time: 7.90
# Episode 739	Max: 0.20 	 Time: 6.34
# Episode 740	Max: 0.10 	 Time: 4.72
# Episode 741	Max: 0.10 	 Time: 4.63
# Episode 742	Max: 0.30 	 Time: 11.01
# Episode 743	Max: 0.10 	 Time: 4.62
# Episode 744	Max: 0.00 	 Time: 1.26
# Episode 745	Max: 0.10 	 Time: 4.62
# Episode 746	Max: 0.10 	 Time: 4.67
# Episode 747	Max: 0.09 	 Time: 2.61
# Episode 748	Max: 0.09 	 Time: 4.26
# Episode 749	Max: 0.10 	 Time: 2.58
# Episode 750	Max: 0.10 	 Time: 4.54
# Episode 751	Max: 0.10 	 Time: 2.58
# Episode 752	Max: 0.20 	 Time: 8.11
# Episode 753	Max: 0.10 	 Time: 3.37
# Episode 754	Max: 0.00 	 Time: 1.33
# Episode 755	Max: 0.10 	 Time: 2.58
# Episode 756	Max: 0.09 	 Time: 2.79
# Episode 757	Max: 0.10 	 Time: 4.55
# Episode 758	Max: 0.10 	 Time: 2.83
# Episode 759	Max: 0.20 	 Time: 7.75
# Episode 760	Max: 0.10 	 Time: 2.66
# Episode 761	Max: 0.00 	 Time: 1.35
# Episode 762	Max: 0.00 	 Time: 1.23
# Episode 763	Max: 0.10 	 Time: 4.63
# Episode 764	Max: 0.10 	 Time: 4.77
# Episode 765	Max: 0.10 	 Time: 2.88
# Episode 766	Max: 0.10 	 Time: 2.60
# Episode 767	Max: 0.20 	 Time: 7.82
# Episode 768	Max: 0.10 	 Time: 2.68
# Episode 769	Max: 0.20 	 Time: 6.64
# Episode 770	Max: 0.19 	 Time: 6.24
# Episode 771	Max: 0.10 	 Time: 2.67
# Episode 772	Max: 0.10 	 Time: 2.61
# Episode 773	Max: 0.10 	 Time: 2.66
# Episode 774	Max: 0.19 	 Time: 6.22
# Episode 775	Max: 0.20 	 Time: 8.29
# Episode 776	Max: 0.20 	 Time: 6.31
# Episode 777	Max: 0.10 	 Time: 2.68
# Episode 778	Max: 0.20 	 Time: 6.18
# Episode 779	Max: 0.10 	 Time: 4.63
# Episode 780	Max: 0.10 	 Time: 4.68
# Episode 781	Max: 0.20 	 Time: 8.02
# Episode 782	Max: 0.10 	 Time: 4.54
# Episode 783	Max: 0.20 	 Time: 6.42
# Episode 784	Max: 0.10 	 Time: 2.68
# Episode 785	Max: 0.20 	 Time: 8.07
# Episode 786	Max: 0.20 	 Time: 8.07
# Episode 787	Max: 0.10 	 Time: 4.62
# Episode 788	Max: 0.10 	 Time: 2.74
# Episode 789	Max: 0.10 	 Time: 2.62
# Episode 790	Max: 0.20 	 Time: 6.08
# Episode 791	Max: 0.30 	 Time: 9.79
# Episode 792	Max: 0.30 	 Time: 9.71
# Episode 793	Max: 0.20 	 Time: 8.03
# Episode 794	Max: 0.10 	 Time: 2.85
# Episode 795	Max: 0.10 	 Time: 2.76
# Episode 796	Max: 0.20 	 Time: 7.97
# Episode 797	Max: 0.10 	 Time: 2.78
# Episode 798	Max: 0.20 	 Time: 6.13
# Episode 799	Max: 0.19 	 Time: 6.32
# Episode 800	Max: 0.20 	 Time: 6.32
# Episode 801	Max: 0.10 	 Time: 2.75
# Episode 802	Max: 0.10 	 Time: 5.85
# Episode 803	Max: 0.10 	 Time: 2.69
# Episode 804	Max: 0.30 	 Time: 11.48
# Episode 805	Max: 0.20 	 Time: 6.31
# Episode 806	Max: 0.20 	 Time: 6.34
# Episode 807	Max: 0.10 	 Time: 2.67
# Episode 808	Max: 0.10 	 Time: 2.67
# Episode 809	Max: 0.20 	 Time: 6.34
# Episode 810	Max: 0.10 	 Time: 4.57
# Episode 811	Max: 0.10 	 Time: 4.53
# Episode 812	Max: 0.10 	 Time: 2.68
# Episode 813	Max: 0.10 	 Time: 2.77
# Episode 814	Max: 0.10 	 Time: 2.75
# Episode 815	Max: 0.00 	 Time: 1.34
# Episode 816	Max: 0.00 	 Time: 1.27
# Episode 817	Max: 0.10 	 Time: 2.76
# Episode 818	Max: 0.00 	 Time: 1.26
# Episode 819	Max: 0.00 	 Time: 1.24
# Episode 820	Max: 0.00 	 Time: 1.26
# Episode 821	Max: 0.00 	 Time: 1.34
# Episode 822	Max: 0.00 	 Time: 1.25
# Episode 823	Max: 0.00 	 Time: 1.24
# Episode 824	Max: 0.10 	 Time: 2.76
# Episode 825	Max: 0.09 	 Time: 2.76
# Episode 826	Max: 0.50 	 Time: 16.48
# Episode 827	Max: 0.20 	 Time: 8.03
# Episode 828	Max: 0.10 	 Time: 2.67
# Episode 829	Max: 0.20 	 Time: 6.39
# Episode 830	Max: 0.10 	 Time: 2.56
# Episode 831	Max: 0.10 	 Time: 2.67
# Episode 832	Max: 0.10 	 Time: 4.56
# Episode 833	Max: 0.20 	 Time: 7.89
# Episode 834	Max: 0.20 	 Time: 6.15
# Episode 835	Max: 0.10 	 Time: 4.53
# Episode 836	Max: 0.00 	 Time: 1.24
# Episode 837	Max: 0.00 	 Time: 1.15
# Episode 838	Max: 0.10 	 Time: 4.65
# Episode 839	Max: 0.10 	 Time: 2.56
# Episode 840	Max: 0.50 	 Time: 16.52
# Episode 841	Max: 0.20 	 Time: 6.41
# Episode 842	Max: 0.10 	 Time: 2.58
# Episode 843	Max: 0.10 	 Time: 2.75
# Episode 844	Max: 0.10 	 Time: 2.81
# Episode 845	Max: 0.10 	 Time: 4.63
# Episode 846	Max: 0.20 	 Time: 8.00
# Episode 847	Max: 0.30 	 Time: 11.08
# Episode 848	Max: 0.90 	 Time: 31.81
# Episode 849	Max: 0.50 	 Time: 18.15
# Episode 850	Max: 0.20 	 Time: 7.91
# Episode 851	Max: 0.09 	 Time: 2.68
# Episode 852	Max: 0.30 	 Time: 9.73
# Episode 853	Max: 0.30 	 Time: 9.72
# Episode 854	Max: 0.10 	 Time: 2.67
# Episode 855	Max: 0.39 	 Time: 13.09
# Episode 856	Max: 0.20 	 Time: 7.91
# Episode 857	Max: 0.10 	 Time: 2.64
# Episode 858	Max: 0.30 	 Time: 11.33
# Episode 859	Max: 0.10 	 Time: 2.69
# Episode 860	Max: 0.20 	 Time: 8.70
# Episode 861	Max: 0.00 	 Time: 1.25
# Episode 862	Max: 0.50 	 Time: 16.42
# Episode 863	Max: 0.00 	 Time: 1.16
# Episode 864	Max: 0.40 	 Time: 14.80
# Episode 865	Max: 0.50 	 Time: 16.38
# Episode 866	Max: 1.10 	 Time: 36.93
# Episode 867	Max: 0.20 	 Time: 6.23
# Episode 868	Max: 0.10 	 Time: 2.80
# Episode 869	Max: 0.10 	 Time: 4.55
# Episode 870	Max: 1.00 	 Time: 35.39
# Episode 871	Max: 0.09 	 Time: 2.85
# Episode 872	Max: 0.10 	 Time: 2.89
# Episode 873	Max: 0.09 	 Time: 2.71
# Episode 874	Max: 0.20 	 Time: 8.02
# Episode 875	Max: 1.30 	 Time: 43.70
# Episode 876	Max: 0.20 	 Time: 7.97
# Episode 877	Max: 0.10 	 Time: 4.69
# Episode 878	Max: 0.20 	 Time: 6.13
# Episode 879	Max: 0.09 	 Time: 2.68
# Episode 880	Max: 0.20 	 Time: 7.95
# Episode 881	Max: 0.40 	 Time: 14.88
# Episode 882	Max: 1.00 	 Time: 35.24
# Episode 883	Max: 1.59 	 Time: 54.01
# Episode 884	Max: 0.00 	 Time: 1.26
# Episode 885	Max: 2.60 	 Time: 89.24
# Episode 886	Max: 0.20 	 Time: 7.05
# Episode 887	Max: 0.00 	 Time: 1.23
# Episode 888	Max: 0.00 	 Time: 1.15
# Episode 889	Max: 0.50 	 Time: 16.55
# Episode 890	Max: 0.00 	 Time: 1.25
# Episode 891	Max: 2.60 	 Time: 89.50
# Episode 892	Max: 0.10 	 Time: 3.75
# Episode 893	Max: 2.40 	 Time: 81.01
# Episode 894	Max: 2.20 	 Time: 75.76
# Episode 895	Max: 0.10 	 Time: 2.66
# Episode 896	Max: 0.10 	 Time: 2.86
# Episode 897	Max: 0.50 	 Time: 16.54
# Episode 898	Max: 0.50 	 Time: 16.41
# Episode 899	Max: 0.20 	 Time: 6.12
# Episode 900	Max: 0.80 	 Time: 28.36
# Episode 901	Max: 0.30 	 Time: 9.64
# Episode 902	Max: 1.20 	 Time: 40.37
# Episode 903	Max: 0.30 	 Time: 11.42
# Episode 904	Max: 1.10 	 Time: 38.45
# Episode 905	Max: 0.50 	 Time: 16.40
# Episode 906	Max: 0.00 	 Time: 1.25
# Episode 907	Max: 0.60 	 Time: 19.72
# Episode 908	Max: 0.40 	 Time: 14.67
# Episode 909	Max: 0.20 	 Time: 7.99
# Episode 910	Max: 0.30 	 Time: 9.73
# Episode 911	Max: 0.10 	 Time: 2.69
# Episode 912	Max: 0.20 	 Time: 6.23
# Episode 913	Max: 0.20 	 Time: 6.13
# Episode 914	Max: 0.00 	 Time: 1.25
# Episode 915	Max: 0.40 	 Time: 14.60
# Episode 916	Max: 0.30 	 Time: 9.57
# Episode 917	Max: 0.20 	 Time: 6.15
# Episode 918	Max: 0.00 	 Time: 1.25
# Episode 919	Max: 0.50 	 Time: 18.07
# Episode 920	Max: 0.00 	 Time: 1.24
# Episode 921	Max: 0.60 	 Time: 19.69
# Episode 922	Max: 0.20 	 Time: 6.15
# Episode 923	Max: 0.40 	 Time: 15.15
# Episode 924	Max: 0.20 	 Time: 6.14
# Episode 925	Max: 0.30 	 Time: 13.27
# Episode 926	Max: 0.09 	 Time: 2.69
# Episode 927	Max: 0.30 	 Time: 9.72
# Episode 928	Max: 0.40 	 Time: 14.76
# Episode 929	Max: 0.40 	 Time: 13.05
# Episode 930	Max: 0.20 	 Time: 6.15
# Episode 931	Max: 0.49 	 Time: 17.71
# Episode 932	Max: 0.70 	 Time: 23.14
# Episode 933	Max: 0.20 	 Time: 7.92
# Episode 934	Max: 0.10 	 Time: 2.80
# Episode 935	Max: 0.10 	 Time: 2.67
# Episode 936	Max: 0.20 	 Time: 8.01
# Episode 937	Max: 0.10 	 Time: 2.68
# Episode 938	Max: 0.30 	 Time: 11.33
# Episode 939	Max: 0.30 	 Time: 11.31
# Episode 940	Max: 0.30 	 Time: 9.64
# Episode 941	Max: 0.40 	 Time: 12.99
# Episode 942	Max: 0.10 	 Time: 2.78
# Episode 943	Max: 0.10 	 Time: 4.54
# Episode 944	Max: 0.40 	 Time: 14.73
# Episode 945	Max: 0.30 	 Time: 11.29
# Episode 946	Max: 0.40 	 Time: 14.72
# Episode 947	Max: 0.10 	 Time: 2.60
# Episode 948	Max: 0.00 	 Time: 1.34
# Episode 949	Max: 0.50 	 Time: 16.38
# Episode 950	Max: 0.10 	 Time: 2.59
# Episode 951	Max: 0.00 	 Time: 1.36
# Episode 952	Max: 0.00 	 Time: 1.27
# Episode 953	Max: 0.00 	 Time: 1.23
# Episode 954	Max: 0.10 	 Time: 4.56
# Episode 955	Max: 0.10 	 Time: 2.56
# Episode 956	Max: 0.30 	 Time: 9.76
# Episode 957	Max: 0.10 	 Time: 2.60
# Episode 958	Max: 0.10 	 Time: 2.54
# Episode 959	Max: 0.10 	 Time: 3.73
# Episode 960	Max: 0.19 	 Time: 6.04
# Episode 961	Max: 0.10 	 Time: 2.74
# Episode 962	Max: 0.20 	 Time: 7.91
# Episode 963	Max: 0.10 	 Time: 2.79
# Episode 964	Max: 0.10 	 Time: 4.55
# Episode 965	Max: 0.80 	 Time: 26.74
# Episode 966	Max: 0.10 	 Time: 2.67
# Episode 967	Max: 0.90 	 Time: 31.71
# Episode 968	Max: 0.90 	 Time: 31.72
# Episode 969	Max: 1.10 	 Time: 38.64
# Episode 970	Max: 0.20 	 Time: 6.22
# Episode 971	Max: 1.10 	 Time: 36.73
# Episode 972	Max: 0.10 	 Time: 2.87
# Episode 973	Max: 0.10 	 Time: 2.86
# Episode 974	Max: 0.50 	 Time: 18.06
# Episode 975	Max: 0.20 	 Time: 7.89
# Episode 976	Max: 0.10 	 Time: 2.77
# Episode 977	Max: 0.10 	 Time: 2.70
# Episode 978	Max: 0.10 	 Time: 2.85
# Episode 979	Max: 0.40 	 Time: 12.95
# Episode 980	Max: 0.10 	 Time: 2.89
# Episode 981	Max: 0.10 	 Time: 2.83
# Episode 982	Max: 0.10 	 Time: 2.68
# Episode 983	Max: 0.30 	 Time: 9.64
# Episode 984	Max: 0.10 	 Time: 2.59
# Episode 985	Max: 0.10 	 Time: 2.79
# Episode 986	Max: 0.60 	 Time: 21.62
# Episode 987	Max: 0.10 	 Time: 2.87
# Episode 988	Max: 0.20 	 Time: 7.95
# Episode 989	Max: 0.10 	 Time: 2.76
# Episode 990	Max: 0.10 	 Time: 2.86
# Episode 991	Max: 0.20 	 Time: 7.95
# Episode 992	Max: 0.10 	 Time: 4.63
# Episode 993	Max: 0.30 	 Time: 9.68
# Episode 994	Max: 0.40 	 Time: 13.11
# Episode 995	Max: 0.40 	 Time: 13.02
# Episode 996	Max: 1.00 	 Time: 35.05
# Episode 997	Max: 0.10 	 Time: 2.88
# Episode 998	Max: 1.00 	 Time: 33.45
# Episode 999	Max: 1.10 	 Time: 38.70
# Episode 1000	Max: 0.20 	 Time: 6.21
# Episode 1001	Max: 1.20 	 Time: 40.28
# Episode 1002	Max: 0.30 	 Time: 9.77
# Episode 1003	Max: 0.40 	 Time: 13.07
# Episode 1004	Max: 0.20 	 Time: 6.17
# Episode 1005	Max: 0.19 	 Time: 4.45
# Episode 1006	Max: 2.30 	 Time: 77.70
# Episode 1007	Max: 0.10 	 Time: 3.11
# Episode 1008	Max: 0.09 	 Time: 2.80
# Episode 1009	Max: 0.30 	 Time: 11.39
# Episode 1010	Max: 0.10 	 Time: 2.80
# Episode 1011	Max: 0.30 	 Time: 11.27
# Episode 1012	Max: 0.20 	 Time: 7.90
# Episode 1013	Max: 0.10 	 Time: 2.78
# Episode 1014	Max: 0.50 	 Time: 16.41
# Episode 1015	Max: 0.10 	 Time: 2.68
# Episode 1016	Max: 1.90 	 Time: 63.87
# Episode 1017	Max: 0.70 	 Time: 25.14
# Episode 1018	Max: 2.60 	 Time: 89.57
# Episode 1019	Max: 0.09 	 Time: 1.88
# Episode 1020	Max: 2.60 	 Time: 89.54
# Episode 1021	Max: 0.80 	 Time: 26.21
# Episode 1022	Max: 0.00 	 Time: 1.14
# Episode 1023	Max: 1.90 	 Time: 63.90
# Episode 1024	Max: 0.10 	 Time: 2.70
# Episode 1025	Max: 0.90 	 Time: 31.59
# Episode 1026	Max: 2.60 	 Time: 89.41
# Episode 1027	Max: 0.70 	 Time: 24.07
# Episode 1028	Max: 0.00 	 Time: 1.16
# Episode 1029	Max: 1.00 	 Time: 35.53
# Episode 1030	Max: 0.00 	 Time: 1.16
# Episode 1031	Max: 2.30 	 Time: 79.59
# Episode 1032	Max: 2.60 	 Time: 89.77
# Episode 1033	Max: 2.20 	 Time: 75.06
# Episode 1034	Max: 2.60 	 Time: 90.01
# Episode 1035	Max: 0.09 	 Time: 1.97
# Episode 1036	Max: 2.50 	 Time: 86.26
# Episode 1037	Max: 0.10 	 Time: 4.62
# Episode 1038	Max: 2.30 	 Time: 79.49
# Episode 1039	Max: 0.10 	 Time: 4.63
# Episode 1040	Max: 1.30 	 Time: 45.54
# Episode 1041	Max: 2.60 	 Time: 90.27
# Episode 1042	Max: 0.10 	 Time: 1.96
# Episode 1043	Max: 2.60 	 Time: 89.52
# Episode 1044	Max: 0.10 	 Time: 1.78
# Episode 1045	Max: 2.60 	 Time: 89.30
# Episode 1046	Max: 2.70 	 Time: 89.76
# Episode 1047	Max: 2.60 	 Time: 89.54
# Episode 1048	Max: 0.60 	 Time: 20.45
# Episode 1049	Max: 0.10 	 Time: 4.54
# Episode 1050	Max: 2.60 	 Time: 89.66
# Episode 1051	Max: 0.09 	 Time: 1.95
# Episode 1052	Max: 2.10 	 Time: 71.83
# Episode 1053	Max: 0.10 	 Time: 2.69
# Episode 1054	Max: 0.10 	 Time: 4.22
# Episode 1055	Max: 0.10 	 Time: 2.79
# Episode 1056	Max: 0.00 	 Time: 1.17
# Episode 1057	Max: 0.50 	 Time: 18.24
# Episode 1058	Max: 2.60 	 Time: 89.71
# Episode 1059	Max: 0.09 	 Time: 1.99
# Episode 1060	Max: 2.60 	 Time: 89.81
# Episode 1061	Max: 2.70 	 Time: 89.71
# Episode 1062	Max: 2.60 	 Time: 89.63
# Episode 1063	Max: 2.70 	 Time: 92.50
# Episode 1064	Max: 2.60 	 Time: 91.09
# Episode 1065	Max: 0.10 	 Time: 2.96
# Episode 1066	Max: 0.09 	 Time: 2.84
# Episode 1067	Max: 2.60 	 Time: 90.02
# Episode 1068	Max: 0.10 	 Time: 1.98
# Episode 1069	Max: 2.60 	 Time: 89.61
# Episode 1070	Max: 0.20 	 Time: 7.21
# Episode 1071	Max: 2.60 	 Time: 89.64
# Episode 1072	Max: 0.10 	 Time: 1.96
# Episode 1073	Max: 0.00 	 Time: 1.18
# Episode 1074	Max: 2.60 	 Time: 89.96
# Episode 1075	Max: 2.70 	 Time: 89.18
# Episode 1076	Max: 2.60 	 Time: 88.71
# Episode 1077	Max: 2.70 	 Time: 89.40
# Episode 1078	Max: 2.60 	 Time: 88.85
# Episode 1079	Max: 2.70 	 Time: 88.88
# Episode 1080	Max: 0.10 	 Time: 2.29
# Episode 1081	Max: 2.60 	 Time: 88.75
# Episode 1082	Max: 0.10 	 Time: 1.87
# Episode 1083	Max: 2.60 	 Time: 89.46
# Episode 1084	Max: 0.10 	 Time: 1.96
# Episode 1085	Max: 0.20 	 Time: 7.87
# Episode 1086	Max: 2.60 	 Time: 88.96
# Episode 1087	Max: 0.10 	 Time: 1.96
# Episode 1088	Max: 0.00 	 Time: 1.15
# Episode 1089	Max: 2.60 	 Time: 89.30
# Episode 1090	Max: 0.10 	 Time: 1.93
# Episode 1091	Max: 2.60 	 Time: 89.23
# Episode 1092	Max: 0.10 	 Time: 1.97
# Episode 1093	Max: 2.60 	 Time: 89.05
# Episode 1094	Max: 0.10 	 Time: 1.88
# Episode 1095	Max: 2.60 	 Time: 89.86
# Episode 1096	Max: 0.10 	 Time: 1.97
# Episode 1097	Max: 2.60 	 Time: 89.39
# Episode 1098	Max: 1.20 	 Time: 40.68
# Episode 1099	Max: 0.09 	 Time: 2.68
# Episode 1100	Max: 2.60 	 Time: 88.92
# Episode 1101	Max: 2.70 	 Time: 89.03
# Episode 1102	Max: 2.60 	 Time: 89.32
# Episode 1103	Max: 2.70 	 Time: 88.93
# Episode 1104	Max: 2.60 	 Time: 89.45
# Episode 1105	Max: 2.70 	 Time: 89.12
# Episode 1106	Max: 0.00 	 Time: 0.53
# Episode 1107	Max: 2.60 	 Time: 89.05
# Episode 1108	Max: 2.30 	 Time: 76.39
# Episode 1109	Max: 2.60 	 Time: 89.65
# Episode 1110	Max: 2.70 	 Time: 90.76
# Episode 1111	Max: 2.60 	 Time: 90.64
# Episode 1112	Max: 2.70 	 Time: 90.89
# Episode 1113	Max: 2.60 	 Time: 90.59
# Episode 1114	Max: 2.70 	 Time: 90.32
# Episode 1115	Max: 2.60 	 Time: 90.04
# Episode 1116	Max: 2.70 	 Time: 90.21
# Episode 1117	Max: 0.10 	 Time: 3.58
# Episode 1118	Max: 2.60 	 Time: 90.19
# Episode 1119	Max: 0.50 	 Time: 17.42
# Episode 1120	Max: 0.10 	 Time: 4.60
# Episode 1121	Max: 2.60 	 Time: 90.20
# Episode 1122	Max: 0.10 	 Time: 1.90
# Episode 1123	Max: 2.60 	 Time: 92.32
# Episode 1124	Max: 0.30 	 Time: 10.88
# Episode 1125	Max: 2.60 	 Time: 92.24
# Episode 1126	Max: 2.70 	 Time: 94.05
# Episode 1127	Max: 2.60 	 Time: 93.24
# Episode 1128	Max: 2.70 	 Time: 94.85
# Episode 1129	Max: 2.60 	 Time: 115.80
# Episode 1130	Max: 2.70 	 Time: 96.18
# Episode 1131	Max: 0.20 	 Time: 5.85
# Episode 1132	Max: 2.60 	 Time: 90.69
# Episode 1133	Max: 2.70 	 Time: 90.79
# Episode 1134	Max: 2.60 	 Time: 91.33
# Episode 1135	Max: 2.70 	 Time: 91.58
# Episode 1136	Max: 0.10 	 Time: 2.47
# Episode 1137	Max: 2.60 	 Time: 90.35
# Episode 1138	Max: 2.70 	 Time: 90.04
# Episode 1139	Max: 2.60 	 Time: 90.00
# Episode 1140	Max: 2.70 	 Time: 90.17
# Episode 1141	Max: 2.60 	 Time: 89.97
# Episode 1142	Max: 0.10 	 Time: 3.23
# Episode 1143	Max: 2.60 	 Time: 91.05
# Episode 1144	Max: 0.10 	 Time: 1.97
# Episode 1145	Max: 2.60 	 Time: 89.71
# Episode 1146	Max: 2.70 	 Time: 90.00
# Episode 1147	Max: 2.60 	 Time: 90.20
# Episode 1148	Max: 2.70 	 Time: 90.46
# Episode 1149	Max: 2.60 	 Time: 89.87
# Episode 1150	Max: 2.70 	 Time: 90.26
# Episode 1151	Max: 0.10 	 Time: 2.24
# Episode 1152	Max: 2.60 	 Time: 90.56
# Episode 1153	Max: 0.10 	 Time: 1.87
# Episode 1154	Max: 2.60 	 Time: 89.96
# Episode 1155	Max: 2.70 	 Time: 90.01
# Episode 1156	Max: 2.60 	 Time: 90.47
# Episode 1157	Max: 2.70 	 Time: 89.82
# Episode 1158	Max: 2.60 	 Time: 90.41
# Episode 1159	Max: 0.10 	 Time: 3.25
# Episode 1160	Max: 2.60 	 Time: 90.62
# Episode 1161	Max: 2.00 	 Time: 68.65
# Episode 1162	Max: 2.60 	 Time: 95.77
# Episode 1163	Max: 2.70 	 Time: 90.20
# Episode 1164	Max: 2.60 	 Time: 91.96
# Episode 1165	Max: 2.70 	 Time: 91.55
# Episode 1166	Max: 2.60 	 Time: 91.51
# Episode 1167	Max: 0.10 	 Time: 1.46
# Episode 1168	Max: 2.60 	 Time: 93.17
# Episode 1169	Max: 2.70 	 Time: 95.35
# Episode 1170	Max: 2.60 	 Time: 93.92
# Episode 1171	Max: 2.70 	 Time: 94.44
# Episode 1172	Max: 2.60 	 Time: 93.67
# Episode 1173	Max: 2.70 	 Time: 93.08
# Episode 1174	Max: 2.60 	 Time: 93.65
# Episode 1175	Max: 2.70 	 Time: 95.26
# Episode 1176	Max: 2.70 	 Time: 96.06
# Episode 1177	Max: 2.60 	 Time: 92.60
# Episode 1178	Max: 2.70 	 Time: 91.80
# Episode 1179	Max: 2.60 	 Time: 92.64
# Episode 1180	Max: 2.70 	 Time: 91.85
# Episode 1181	Max: 2.60 	 Time: 92.52
# Timestep 171747	Max: 0.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-69ffd0cc2d08> in <module>
#       1 agents = D4PGAgent(params=params['agent_params'])
#       2
# ----> 3 scores = train(agents=agents, params=params, num_processes=num_agents)
#       4
#       5 df = pd.DataFrame(data={'episode': np.arange(len(scores)), 'D4PG': scores})
#
# D:\Dropbox\Coding\AI\Udacity\Deep Reinforcement Learning\deep-reinforcement-learning\p3_collab-compet\train.py in train(agents, params, num_processes)
#      69                     adjusted_rewards[0] = adjusted_rewards[1] * params['alternative_reward_scalar']
#      70
# ---> 71             actor_loss, critic_loss = agents.step(states, actions, adjusted_rewards, next_states, dones, pretrain = pretrain)
#      72             if actor_loss != None and critic_loss != None:
#      73
#
# D:\Dropbox\Coding\AI\Udacity\Deep Reinforcement Learning\deep-reinforcement-learning\p3_collab-compet\agent.py in step(self, states, actions, rewards, next_states, dones, pretrain)
#     259
#     260         if pretrain == False:
# --> 261             return self.learn_()
#     262
#     263         return None, None
#
# D:\Dropbox\Coding\AI\Udacity\Deep Reinforcement Learning\deep-reinforcement-learning\p3_collab-compet\agent.py in learn_(self)
#     286                     # Calculate the projected log probabilities from the target actor and critic networks
#     287                     # Since back propogation is not required. Tensors are detach to increase speed
# --> 288                     target_dist = self._get_targets(rewards, next_states).detach()
#     289
#     290                     # The critic loss is calculated using a weighted distribution instead of the mean to
#
# D:\Dropbox\Coding\AI\Udacity\Deep Reinforcement Learning\deep-reinforcement-learning\p3_collab-compet\agent.py in _get_targets(self, rewards, next_states)
#     351
#     352         # Project the categorical distribution
# --> 353         projected_probs = self._get_value_distribution(rewards, target_probs)
#     354         return projected_probs
#     355
#
# D:\Dropbox\Coding\AI\Udacity\Deep Reinforcement Learning\deep-reinforcement-learning\p3_collab-compet\agent.py in _get_value_distribution(self, rewards, probs)
#     385         for idx in range(probs.size(0)):
#     386             projected_probs[idx].index_add_(0, lower_bound[idx].long(), m_lower[idx].double())
# --> 387             projected_probs[idx].index_add_(0, upper_bound[idx].long(), m_upper[idx].double())
#     388         return projected_probs.float()
#     389
#
# KeyboardInterrupt:

# %% [markdown]
# ### Future Improvements
#
# #### Prioritized Experience Replay
# By prioritizing the experiences and learning from experiences with 'more to learn from' will most likely result to faster convergence.
#
# #### Annealing of Gaussian Noise
# The agent is currently using Gaussian Noise to encourage exploration of the action space. A noise factor of epsilon 0.3 is used consistently throughout the training. Annealing this to lower values based on performance once the agent comes close to convergence may result in higher maximum scores
